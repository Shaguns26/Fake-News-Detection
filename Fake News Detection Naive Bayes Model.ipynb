# %%
import pandas as pd
import numpy as np

# %%
truenews = pd.read_csv('true.csv')
fakenews = pd.read_csv('fake.csv')

# %%
fakenews.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
truenews.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fakenews.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
truenews.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
truenews['True/Fake']='True'
fakenews['True/Fake']='Fake'

# %%
# Combine the 2 DataFrames into a single data frame
news = pd.concat([truenews, fakenews])
news["Article"] = news["title"] + news["text"]
news.sample(frac = 1) #Shuffle 100%
# Out:
#                                                    title  \
# 14654  Youth leader of Zimbabwe's ruling party apolog...
# 18544  SEWER WORKER DIES After Muslim Doctors REFUSE ...
# 5430    Slain Officer Had Just Written These Emotiona...
# 16427  THE POPE PUSHES CLIMATE JUSTICE : “Ambitious A...
# 959     A Panicked Trump Ran Around The White House A...
# 14068  Israeli official under fire for comments on Am...
# 13718  WATCH: JUAN HERNANDEZ Tells How He Was CHASED ...
# 18833  OOPS! DOCTOR DRAGGED Off United Airlines Fligh...
# 2977    Green Day Just Gave Trump The ULTIMATE Pre-In...
# 13758  Turkish PM says EU confused since Brexit, need...
# 7996    Morgan Freeman, America’s Most Beloved Narrat...
# 13012  BOOM! WATCH TRUMP IN FLINT: “Now, the Cars are...
# 11572  Cuba delays historic handover from Castro to n...
# 13335  Turkey to seize assets of gold trader testifyi...
# 4119   Sweet home Chicago: Obama re-emerges in city w...
# 3584    Trump Meets Anti-Vaccination Nuts And Express...
# 3323    Trump Gets Hilariously OWNED For Whining Abou...
# 18463  BOOM! JOHN SUNUNU: “Bothers Me That Mueller Is...
# 6030   Trump to choose U.S. Supreme Court justice nom...
# 16984  Putin says doubts U.S. strike on North Korea w...
# 10274  U.S. general Lori Robinson to become first wom...
# 13305  BREAKING: Did Hillary’s Unsecured CLASSIFIED E...
# 23453  Plastic Persona: Behind the Scenes of the Ted ...
# 21124  DID IRAN RELEASE This Footage Of Captured U.S....
# 8978   British EU exit a model for Trump's campaign, ...
# 14349  German president says all parties have duty to...
# 6271   Trump accuses civil rights leader Lewis of lyi...
# 18984  Ireland set to vote on loosening abortion laws...
# 16503  NO RESPECT! US DIPLOMAT ATTACKED By Russian Gu...
# 3486   U.S. companies sign billions in deals with Vie...
# ...                                                  ...
# 5054    Trump Has F*cked Up So Much Lately His Own Ad...
# 6838   Trump could privatize nation's air traffic con...
# 10674  WINNING! TRUMP STOPS Obama-Era DOJ “Slush Fund...
# 158    Kentucky lawmaker a 'probable suicide' amid se...
# 4009   Exclusive: 'If there's a shutdown, there's a s...
# 16503  NO RESPECT! US DIPLOMAT ATTACKED By Russian Gu...
# 3486   U.S. companies sign billions in deals with Vie...
# ...                                                  ...
# 5054    Trump Has F*cked Up So Much Lately His Own Ad...
# 6838   Trump could privatize nation's air traffic con...
# 10674  WINNING! TRUMP STOPS Obama-Era DOJ “Slush Fund...
# 158    Kentucky lawmaker a 'probable suicide' amid se...
# 4009   Exclusive: 'If there's a shutdown, there's a s...
# 11691  Saudi-led coalition to allow cranes into Yemen...
# 2889   The Trump economy in seven charts WASHINGTON (...
# 19754  Mexican leftist Obrador leads ahead of 2018 el...
# 17674  Migrant deaths in the Sahara likely twice Medi...
# 4523    Hannity Gets His A** Handed To Him For Falsel...
# 16082  LIVE STREAM: PRESIDENT TRUMP’S Historic Speech...
# 16783  Spain urges Catalonia secessionists to obey Ma...
# 2933   States refuse Trump commission request for U.S...
# 11121  BOOM! TRUMP POLL Numbers Going Up…Up…Up! While...
# 15115  Hezbollah says Saudi declares Lebanon war with...
# 15624  Thousands of Romanians protest ruling party's ...
# 3336   Q&A: What we know about U.S. probes of Russian...
# 18681  Blast hits Afghan capital near Shi'ite mosque,...
# 7883   Hurricane Matthew toll in Haiti rises to 1,000...
# 1158    Sandy Hook Mom SHREDS Megyn Kelly For Intervi...
# 23412  HAWKISH DOVE: The Enigma of Donald Trump in Vo...
# 19924  British police 'chasing down suspects' after t...
# 6155   Trump, now president, pledges to put 'America ...
# 8880    Heavily-Armed Man Claiming To Be Jesus Arrest...
# 12301  “RANDOM” PHOTO-OP WITH HILLARY…Not So Random…C...
# 12774  BREAKING: WIKILEAKS RELEASES LIST Of Reporters...
# 5644   Immigration chaos and long nights led to Washi...
# 5709    Former GOP Rep. Says Electing President Obama...
# 16590  New wave of cyber attacks hits Russia, other n...
# 7961    BREAKING: Jeb Bush Suspends Campaign Under Pr...
#
# [44898 rows x 6 columns]

# %%
#Data Cleaning
from nltk.corpus import stopwords
import string

# %%
def process_text(s):

    # Check string to see if they are a punctuation
    nopunc = [char for char in s if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert string to lowercase and remove stopwords
    clean_string = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    return clean_string

# %%
# Tokenize the text :Convert the normal text strings in to a list of tokens (words that we actually want)
#rerun, takes LOOOONG
news['Clean Text'] = news['Article'].apply(process_text)

# %%
news.sample(5)
# Out:
#                                                    title  \
# 17269  'Vanishing village' looks to Japan's LDP for s...
# 19941  Rights groups condemn Saudi arrests as crackdo...
# 6       Fresh Off The Golf Course, Trump Lashes Out A...
# 19532  Tanzania shuts down another 'days numbered' ne...
# 23228  How the FBI Creates ‘Domestic Terror’ in the U...
#
#                                                     text      subject  \
# 17269  NANMOKU, Japan (Reuters) - Chikara Imai, 73, i...    worldnews
# 19941  (Reuters) - The campaign group Human Rights Wa...    worldnews
# 6      Donald Trump spent a good portion of his day a...         News
# 19532  DAR ES SALAAM (Reuters) - Tanzania s governmen...    worldnews
# 23228  21st Century Wire says This is a bit of an odd...  Middle-east
#
#                       date True/Fake  \
# 17269    October 17, 2017       True
# 19941  September 15, 2017       True
# 6        December 23, 2017      Fake
# 19532  September 20, 2017       True
# 23228     October 15, 2016      Fake
#
#                                                  Article  \
# 17269  'Vanishing village' looks to Japan's LDP for s...
# 19941  Rights groups condemn Saudi arrests as crackdo...
# 6       Fresh Off The Golf Course, Trump Lashes Out A...
# 19532  Tanzania shuts down another 'days numbered' ne...
# 23228  How the FBI Creates ‘Domestic Terror’ in the U...
#
#                                               Clean Text
# 17269  [Vanishing, village, looks, Japans, LDP, survi...
# 19941  [Rights, groups, condemn, Saudi, arrests, crac...
# 6      [Fresh, Golf, Course, Trump, Lashes, FBI, Depu...
# 19532  [Tanzania, shuts, another, days, numbered, new...
# 23228  [FBI, Creates, ‘Domestic, Terror’, United, Sta...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])

print(len(bow_transformer.vocabulary_)) #Total vocab words
# Out:
# 39099

# %%
#Bag-of-Words (bow) transform the entire DataFrame of text
news_bow = bow_transformer.transform(news['Clean Text'])

# %%
print('Shape of Sparse Matrix: ', news_bow.shape)
print('Amount of Non-Zero occurences: ', news_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (44898, 39099)
# Amount of Non-Zero occurences:  44898

# %%
sparsity = (100.0 * news_bow.nnz / (news_bow.shape[0] * news_bow.shape[1]))
print('sparsity: {}'.format(round(sparsity)))
# Out:
# sparsity: 0

# %%
#TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(news_bow)
news_tfidf = tfidf_transformer.transform(news_bow)
print(news_tfidf.shape)
# Out:
# (44898, 39099)

# %%
#Train Naive Bayes Model
from sklearn.naive_bayes import MultinomialNB
fakenews_detect_model = MultinomialNB().fit(news_tfidf, news['True/Fake'])

# %%
#Model Evaluation
predictions = fakenews_detect_model.predict(news_tfidf)
print(predictions)
# Out:
# ['True' 'True' 'True' ..., 'Fake' 'Fake' 'Fake']

# %%
from sklearn.metrics import classification_report
print (classification_report(news['True/Fake'], predictions))
# Out:
#              precision    recall  f1-score   support
#
#        Fake       1.00      1.00      1.00     23481
#        True       1.00      1.00      1.00     21417
#
# avg / total       1.00      1.00      1.00     44898

# %%
from sklearn.cross_validation import train_test_split

news_train, news_test, text_train, text_test = train_test_split(news['Article'], news['True/Fake'], test_size=0.3)

print(len(news_train), len(news_test), len(news_train) + len(news_test))
# Out:
# 31428 13470 44898

# %%
#Create Data Pipeline

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=process_text)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])
pipeline.fit(news_train,text_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer(analyzer=<function process_text at 0x0FBEEAE0>, binary=False,
#         decode_error='strict', dtype=<class 'numpy.int64'>,
#         encoding='utf-8', input='content', lowercase=True, max_df=1.0,
#         max_features=None, min_df=1, ngram_range=(1, 1), preprocessor=None,
# ...f=False, use_idf=True)), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])

# %%
predictions = pipeline.predict(news_test)

# %%
print(classification_report(predictions,text_test))
# Out:
#              precision    recall  f1-score   support
#
#        Fake       0.96      0.98      0.97      6880
#        True       0.98      0.95      0.96      6590
#
# avg / total       0.97      0.97      0.97     13470
